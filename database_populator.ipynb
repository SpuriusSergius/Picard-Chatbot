# %%
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.9-cp312-cp312-win_amd64.whl.metadata (4.5 kB)
# Downloading psycopg2-2.9.9-cp312-cp312-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 660.6 kB/s eta 0:00:02
#    ---- ----------------------------------- 0.1/1.2 MB 1.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.2/1.2 MB 1.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.3/1.2 MB 1.8 MB/s eta 0:00:01
#    -------------- ------------------------- 0.4/1.2 MB 1.8 MB/s eta 0:00:01
#    --------------- ------------------------ 0.5/1.2 MB 1.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.5/1.2 MB 1.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.5/1.2 MB 1.4 MB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.2 MB 1.3 MB/s eta 0:00:01
#    ------------------- -------------------- 0.6/1.2 MB 1.3 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.2 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.6/1.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.6/1.2 MB 1.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.7/1.2 MB 1.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.2 MB 992.0 kB/s eta 0:00:01
#    ------------------------ --------------- 0.7/1.2 MB 962.6 kB/s eta 0:00:01
#    -------------------------- ------------- 0.8/1.2 MB 939.1 kB/s eta 0:00:01
#    ---------------------------- ----------- 0.8/1.2 MB 971.8 kB/s eta 0:00:01
#    ------------------------------ --------- 0.9/1.2 MB 994.7 kB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.2 MB 994.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 1.1/1.2 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------  1.2/1.2 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.9

# %%
# !pip install pgvector
# Out:
# Collecting pgvector
#   Downloading pgvector-0.2.5-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy in c:\users\szjia\documents\wam\spring 2024\data 340 nlp\final project\.venv\lib\site-packages (from pgvector) (1.26.4)
# Downloading pgvector-0.2.5-py2.py3-none-any.whl (9.6 kB)
# Installing collected packages: pgvector
# Successfully installed pgvector-0.2.5

# %% [markdown]
# ## Create the PGVector database
#
# The goal here is to make a Postgresql relational database and populate it with sentence embeddings. I use PGVector and psycopg2 to do this. The embeddings are used in the chatbot via similarity search to add context to the prompt, a technique called "retrieval augmented generation".

# %%
import json
import psycopg2
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import PGVector
from langchain.schema import Document

# %%
# define an embedding model using a pretrained model from HuggingFace
embedding_model_id = "sentence-transformers/all-MiniLM-L6-v2"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": False}
embedding_model = HuggingFaceEmbeddings(
  model_name=embedding_model_id,
  model_kwargs=model_kwargs,
  encode_kwargs=encode_kwargs,
)
# Out:
# c:\Users\szjia\Documents\WaM\Spring 2024\DATA 340 NLP\Final Project\.venv\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Set up the connection between PGVector and Postgresql, 
# note that database st_line has to be set up beforehand through Postgresql.
CONNECTION_STRING = PGVector.connection_string_from_db_params(
    driver="psycopg2",
    host="localhost",
    port=5432,
    database="st_line",
    user="postgres",
    password="password",
)

COLLECTION_NAME = "character_quotes"
store = PGVector(
    collection_name=COLLECTION_NAME,
    connection_string=CONNECTION_STRING,
    embedding_function=embedding_model
)

# %%
# Connect to PostgreSQL
conn = psycopg2.connect(
    dbname="st_line",
    user="postgres",
    password="password",
    host="localhost",
    port="5432"
)

# Read JSON file
with open('C:/Users/szjia/Documents/WaM/Spring 2024/DATA 340 NLP/Final Project/line_data/lines_by_character.json', 'r', encoding="utf-8") as f:
    data = json.load(f)

# Loop through the data which is the in format of character : [lines] in a key-value pair.
id = 0
for character in data:
    character_name = character
    for quote in data[character]:
      quote_text = quote
      # print(character_name + ": " + quote)
      # use the PGVector connection to encode all character lines and add them into the database as a table.
      store.add_documents(
          [Document(page_content=quote_text, metadata={"document_id": id, "author": character})]
      )
      id += 1

# %% [markdown]
# ## Bug Testing Code
#
# If you are trying to populate your own pgvector database, you do not need to run the code below.

# %%
conn = psycopg2.connect(
    dbname="st_line",
    user="postgres",
    password="iusegmail88",
    host="localhost",
    port="5432"
)
cur = conn.cursor()
# cur.execute("SELECT * FROM character_quotes WHERE character_name IS Picard;")
# cur.close()

# %%
cur.execute("SELECT DISTINCT character_name FROM character_quotes;")
result = cur.fetchall()
print(result)
# Out:
# [('NURIA',), ('HOLO-PICARD',), ('CORIN',), ('MARTHA',), ('MONROE',), ('REED',), ('BEGGAR',), ('KAJADA',), ('KYLE',), ('TALAXIAN',), ('WYKOFF',), ('RABBIT',), ('GAAVRIN',), ('FISHER',), ('GORGON',), ('MORIN',), ('JUNIOR',), ('KANE',), ('GIRL ON BLADES',), ('MULLIBOK',), ('JIMMY',), ('RODRIGUEZ',), ('KRYTON',), ('SKALARR',), ('LINKE',), ('DARA',), ('GIOTTO',), ('LEUCON',), ('PTERA',), ('KARNAS',), ('KAPLAN',), ('IRUDAN',), ('MAKLII',), ('ATTACKER',), ('LAUNCH CONTROL',), ('TAIN',), ('DATHON',), ('NEWSCASTER',), ('NAHSK',), ('KORINAS',), ('SHILAT',), ('DROXINE',), ('DECIUS',), ('TREVIS',), ('QUAICE',), ('JORDAN',), ('RONDON',), ('JOHNNY',), ('MIDRO',), ('GREER',), ('CREW',), ('RYAN',), ('KIPP',), ('MANTOOS',), ('VAREL',), ("TRENA'L",), ('ALICE',), ('BRENT',), ("T'SU",), ('ETHAN',), ('ENINA',), ('KARA',), ('FARRELL',), ('ARRIDOR',), ('SANDAL MAKER',), ('BROSSMER',), ('MEA',), ('JEV',), ('BARMAN',), ("IXTANA'RAX",), ('KINGSLEY',), ('ELDER',), ('MUROC',), ('BENZAN',), ('DORAN',), ('TOLAR',), ('ADMIRAL HAYES',), ('SOONG',), ('NELLEN',), ('PALANTI',), ('BURZAAN',), ('LITO',), ('YOUNG CHAKOTAY',), ('FILM',), ('PAREM',), ('INGLATU',), ('GEGEN',), ("T'KAR",), ('MORA',), ('CROMWELL',), ('DEELA',), ('TACTICAL',), ('BATAI JR',), ("'BRIEN",), ('CLERIC',), ('CASTILLO',), ('MARIE',), ('STUBBS',), ('MAYLOR',), ('COUTU',), ('GILL',), ('JEFFREY',), ('WILDMAN',), ('CHORUS',), ('KUULAN',), ('CLOWN',), ('RICE',), ('ABROM',), ('KELIS',), ('STETHJANEWAY',), ('KORNAN',), ('ULIS',), ('NOCONA',), ('MARKEL',), ('ALL',), ('STARFLEET',), ('CRIER',), ('PORTER',), ('HOLO-SESKA',), ('KAREEN',), ('SETI MESSAGE',), ('ENTEK',), ('VALERIAN',), ('VOTH',), ('BILLY',), ('MUDD',), ("M'PELLA",), ('WELD',), ('MARA',), ('MAVEK',), ('JOXOM',), ('FOREMAN',), ('PIE MAN',), ('MICKEY D',), ('TORIAS',), ('WAINWRIGHT',), ('RIVERS',), ('DOLAK',), ('QUEEN TUVOK',), ('KEEVE',), ('JONES',), ('TALEEN',), ('TAMULA',), ('DANICA',), ('BASS',), ('GIGER',), ('GRANDFATHER',), ('LATARA',), ('SECURITY',), ('MALICIA-MEGAN',), ("J'DAN",), ('KOL-TAI',), ('VEN',), ('MEDIC',), ('JELLICO',), ('GERAL',), ('JARADAN',), ('TV',), ('LENORE',), ('BULLOCK',), ('ROZAHN',), ('THALEN',), ('BOSAAL',), ('KAYRON',), ('JAHN',), ('DATA-MEXICAN',), ('MENDEZ',), ('KORENA',), ('LOQUAR',), ('KLINGONS',), ('ADONIS',), ('STAGEHAND',), ("T'JON",), ('DANNY',), ('EMH-OVERLOOKER',), ('BRENNA',), ('EVEK',), ('STUART REED',), ('NORVA',), ("V'LAR",), ('FITZGERALD',), ('ALBERT',), ('CRAIG',), ('KOMACK',), ('GUL DUKAT',), ('CASSANDRA',), ('KREM',), ('TELLARITE',), ('BRULL',), ('DAMAR',), ('DAROK',), ('JANEWAY',), ('IAN',), ('CHILDRESS',), ('ARBOREAL',), ('JAMIE',), ('VARGAS',), ('MACIAS',), ('OPAKA',), ('TASH',), ('LUCIEN',), ('ZOBRAL',), ('THANN',), ('ANAYA',), ('ANKARI',), ('BUCK',), ('GEORGIA',), ('OLIANA',), ('PRIETO',), ('SAKONNA',), ('MED TECH',), ('ALLOS',), ('KHOURI',), ('SMIKE',), ('FENNIM',), ('YIVEL',), ('RASHELLA',), ('JABIN',), ('JONAS',), ('HUMAN',), ("CH'ANO",), ('ARGYLE',), ('ORUM',), ('HANJUAN',), ('ALTOVAR',), ('NECHEYEV',), ('SURGEON',), ('MADELINE',), ('LADY BEAR',), ('ASTRONOMER',), ('DENNING',), ('SARISH',), ('MALIA',), ('GRANT',), ('AZEN',), ('RESEARCHER',), ('ARDRA',), ('ORACLE',), ('TRYLA',), ('SAKKATH',), ('VANNA',), ('CULLUH',), ('TARSES',), ('CADMAR',), ('ANDORIAN',), ('PLASUS',), ('NATIVE',), ('BOMA',), ('CLAYTON',), ("CH'TARGH",), ('ELEEN',), ('SURAK',), ('KOVAT',), ('GREEN',), ('SUDER',), ('RENHOL',), ('MARPLON',), ('ELASIAN',), ('KOPF',), ('GUINAN',), ('CADET',), ('WEATHER COORDINATOR',), ('TANIS',), ('LAAS',), ('KANG',), ('HOLO-KIM',), ('KASHYK',), ('SEK',), ('BEK',), ("K'TEMANG",), ('AYELBORNE',), ('NICOLE',), ('ORDERLY',), ('MIRANDA',), ('MCKENZIE',), ('JAY GORDON',), ('STEPHAN',), ('MENDROSSEN',), ('PEERS',), ('JAFFEN',), ('RAHMIN',), ('NINERS',), ('EDOUARD',), ('COREY',), ('KESTRA',), ('NAGILUM',), ('DURST',), ('KAZAGO',), ('ADULT NAOMI',), ('RAAKIN',), ('OMAG',), ('NAVIGATOR',), ('COSIMO',), ('ABADDON',), ('LIRIA',), ('MISS GLADSTONE',), ("N'VEK",), ('KROLA',), ('RULAT',), ('CHANDRA',), ( ...

# %%
cur.execute("SELECT * FROM character_quotes WHERE character_name='PICARD';")
result = cur.fetchall()
print(result)
# Out:
# [(47398, 'PICARD', "That'll have to wait."), (47555, 'PICARD', 'Destination?'), (47854, 'PICARD', 'Bags of mostly water?'), (49651, 'PICARD', 'Surrounding the structure.'), (49731, 'PICARD', 'Not something I do easily.'), (46413, 'PICARD', 'I see no charges against us, Your Honour.'), (46414, 'PICARD', 'Guilty. Provisionally.'), (46485, 'PICARD', 'Tune that down! Commander Riker, come in. Can you hear me?'), (46360, 'PICARD', "You will agree, Data, that Starfleet's orders are difficult?"), (46361, 'PICARD', 'As simple as that.'), (46362, 'PICARD', "It's hardly simple, Data, to negotiate a friendly agreement for Starfleet to use the base while at the same time snoop around finding how and why the life form there built it."), (46363, 'PICARD', 'Data, how can you be programmed as a virtual encyclopedia of human information without knowing a simple word like snoop?'), (46364, 'PICARD', 'It means to spy, to sneak.'), (46365, 'PICARD', 'Exactly, yes.'), (46366, 'PICARD', 'Shut off that damned noise. Go to Yellow Alert.'), (46367, 'PICARD', 'Reverse power, full stop.'), (46368, 'PICARD', "That's quite a directive. Would you mind identifying what you are?"), (46369, 'PICARD', 'Data, call medics.'), (46370, 'PICARD', 'He would not have injured you. Do you recognise this, the stun setting?'), (46371, 'PICARD', 'What? That nonsense is centuries behind us.'), (46372, 'PICARD', 'Most certainly I deny it. I agree we still were when humans wore costumes like that, four hundred years ago.'), (46373, 'PICARD', "But even when we wore costumes like that we'd already started to make rapid progress."), (46374, 'PICARD', 'Yes you can, Lieutenant Yar.'), (46375, 'PICARD', "No. The same old story is the one we're meeting now. Self-righteous life forms who are eager not to learn but to prosecute, to judge anything they don't understand or can't tolerate."), (46376, 'PICARD', "We've no fear of what the true facts about us will reveal."), (46377, 'PICARD', 'Sense anything, Commander?'), (46378, 'PICARD', "From this point, no station aboard, repeat no station, for any reason will make use of transmitted signals or intercom. We'll try and take them by surprise. Let's see what this galaxy class starship can do.  Lieutenant, inform engine room to prepare for maximum acceleration."), (46379, 'PICARD', 'Records search, Data. Results of detaching saucer section at high warp velocity.'), (46380, 'PICARD', 'Search theoretical.'), (46381, 'PICARD', "Using print-out only, notify all decks to prepare for maximum acceleration. Now hear this, Maximum, you're entitled to know, means that we'll be pushing our engines well beyond safety limits. Our hope is to surprise whatever that is out there, try and outrun it. Our only other option is to tuck tail between our legs and return to Earth as they demand."), (46382, 'PICARD', 'Stand by. Engage.'), (46383, 'PICARD', 'Steady on that.'), (46384, 'PICARD', "Continue accelerating. Counsellor, at this point I'm open to guesses about what we've just met."), (46385, 'PICARD', 'Beyond?'), (46386, 'PICARD', 'Are you sure?'), (46387, 'PICARD', 'Reverse angle.'), (46388, 'PICARD', 'Worf, inform the engine room we need more.'), (46389, 'PICARD', 'Go to yellow alert. Arm aft photon torpedoes. Place them on ready status.'), (46390, 'PICARD', 'Now hear this. Print-out message, urgent, all stations on all decks. Prepare for emergency saucer sever. You will command the saucer section, Lieutenant.'), (46391, 'PICARD', 'You are a Starfleet officer, Lieutenant.'), (46392, 'PICARD', "Make the mark, Data. Note in ship's log that at this startime, I'm transferring command to the battle bridge."), (46393, 'PICARD', 'Lieutenant, your torpedoes must detonate close enough to the hostile to blind it at the moment we separate.'), (46394, 'PICARD', 'Worf, this is the Captain.'), (46395, 'PICARD', 'At the moment of separation, we will reverse power just enough to get your saucer section out ahead and clear of us.'), (46396, 'PICARD', 'Begin countdown. M ...

# %%
# Close the cursor and connection
cur.close()
conn.close()
